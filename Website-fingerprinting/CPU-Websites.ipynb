# %%
import pandas as pd
import numpy as np

import datetime

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.neighbors import KNeighborsClassifier 
import matplotlib.pyplot as plt  
import seaborn as sns 

# %matplotlib inline
plt.rcParams['figure.figsize'] = [11, 7]

from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix

from glob import glob

from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

# %%
filenames = ["Facebook","Reddit","Linkedin","Yahoo","IMDb","MSN","YouTube","Wikipedia"]


for file in filenames:
    filename = file + ".csv"
    opfile = file + "line" +".pdf"
    df = pd.read_csv(filename)
# Dropping irrelevant columns
    newdf = df.iloc[:, 4:6]
    newdf=newdf.astype(float)
    data = newdf.values 
    data_scaled = scaler.fit_transform(data)
    newdf = pd.DataFrame(data_scaled)
    newdf.rename(columns = {0:'B_net',1:'CPU_load'}, inplace = True) 
#Plotting
    plt.plot(newdf.index.values,newdf.B_net,label='B',color='blue',linewidth='1')
    plt.plot(newdf.index.values,newdf.CPU_load,label='CPU',color='green',linewidth='1')
    plt.xlabel('Time') 
    plt.axis('off')
    plt.ylabel('B') 
    plt.title(file) 
    plt.savefig(opfile, dpi=2000)
    plt.show()

# %%
filenames = ["Facebook","Reddit","Linkedin","Yahoo","IMDb","MSN","YouTube","Wikipedia"]


for file in filenames:
    filename = file + ".csv"
    opfile = file + "scatter" +".pdf"
    df = pd.read_csv(filename)
# Dropping irrelevant columns
    newdf = df.iloc[:, 4:6]
    newdf=newdf.astype(float)
    data = newdf.values 
    data_scaled = scaler.fit_transform(data)
    newdf = pd.DataFrame(data_scaled)
    newdf.rename(columns = {0:'B_net',1:'CPU_load'}, inplace = True) 
#Plotting
    plt.scatter(newdf.index.values,newdf.B_net,label='B',color='blue',linewidth='1')
    plt.scatter(newdf.index.values,newdf.CPU_load,label='CPU',color='green',linewidth='1')
    plt.xlabel('Time') 
    plt.axis('off')
    plt.ylabel('B') 
    plt.title(file) 
    plt.savefig(opfile, dpi=2000)
    plt.show()
