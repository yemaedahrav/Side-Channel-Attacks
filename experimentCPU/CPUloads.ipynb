# %%
import pandas as pd
import numpy as np

import datetime

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.neighbors import KNeighborsClassifier 
import matplotlib.pyplot as plt  
import seaborn as sns 

# %matplotlib inline
plt.rcParams['figure.figsize'] = [11, 7]

from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix

from glob import glob

from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

# %%
filenames = ["AdobeReader","Excel","Word","PowerPoint","SnapChat","Messenger","PicsArt","TripAdvisor","Linkedin","Facebook"]


for file in filenames:
    filename = file + ".csv"
    opfile = file + "line" +".pdf"
    df = pd.read_csv(filename)
# Dropping irrelevant columns
    indexNames = df[ df["B_net"] == "B_net" ].index
    df.drop(indexNames , inplace=True)
    newdf = df[["B_net","CPU_load"]]
    newdf=newdf.astype(float)
    data = newdf.values 
    data_scaled = scaler.fit_transform(data)
    newdf = pd.DataFrame(data_scaled)
    newdf.rename(columns = {0:'B_net',1:'CPU_load'}, inplace = True) 
#Plotting
    plt.plot(newdf.index.values,newdf.B_net,label='B',color='blue',linewidth='1')
    plt.plot(newdf.index.values,newdf.CPU_load,label='CPU',color='green',linewidth='1')
    plt.xlabel('Time') 
    plt.axis('off')
    plt.ylabel('B') 
    plt.title(file) 
    plt.savefig(opfile, dpi=2000)
    plt.show() 
    
# print(filenames)
# print(type(filenames))
# print(type(filenames[0]))
# Out:
# /home/iit/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
df = pd.read_csv("AdobeReader.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3977 entries, 0 to 3976
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TimeStamp  3977 non-null   object
#  1   B_x        3977 non-null   object
#  2   B_y        3977 non-null   object
#  3   B_z        3977 non-null   object
#  4   B_net      3977 non-null   object
#  5   CPU_load   3977 non-null   object
# dtypes: object(6)
# memory usage: 186.5+ KB

# %%
indexNames = df[ df["B_net"] == "B_net" ].index
df.drop(indexNames , inplace=True)
df.head()
df.info()
newdf = df[["B_net","CPU_load"]]
newdf=newdf.astype(float)
data = newdf.values 
data_scaled = scaler.fit_transform(data)
newdf = pd.DataFrame(data_scaled)
newdf.rename(columns = {0:'B_net',1:'CPU_load'}, inplace = True) 
newdf.head()
#newdf.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3973 entries, 0 to 3976
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TimeStamp  3973 non-null   object
#  1   B_x        3973 non-null   object
#  2   B_y        3973 non-null   object
#  3   B_z        3973 non-null   object
#  4   B_net      3973 non-null   object
#  5   CPU_load   3973 non-null   object
# dtypes: object(6)
# memory usage: 217.3+ KB
#    B_net  CPU_load
# 0   1.00  0.000000
# 1   1.00  0.226415
# 2   1.00  0.509434
# 3   0.75  0.386792
# 4   0.75  0.235849

# %%
for file in filenames:
    filename = file + ".csv"
    opfile = file + "scatter" + ".pdf"
    df = pd.read_csv(filename)
# Dropping irrelevant columns
    indexNames = df[ df["B_net"] == "B_net" ].index
    df.drop(indexNames , inplace=True)
    newdf = df[["B_net","CPU_load"]]
    newdf=newdf.astype(float)
    data = newdf.values 
    data_scaled = scaler.fit_transform(data)
    newdf = pd.DataFrame(data_scaled)
    newdf.rename(columns = {0:'B_net',1:'CPU_load'}, inplace = True) 
#Plotting
    plt.scatter(newdf.index.values,newdf.B_net,label='B',color='blue',marker="*",linewidth='1')
    plt.scatter(newdf.index.values,newdf.CPU_load,label='CPU',color='green',marker="*",linewidth='1')
    plt.xlabel('Time') 
    plt.axis('off')
    plt.ylabel('B') 
    plt.title(file) 
    plt.legend()
    plt.savefig(opfile, dpi=2000)
    plt.show()
# Out:
# /home/iit/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
